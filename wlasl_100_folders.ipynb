# %%
import os
import json

import pickle

# %%
wlasl_videos_folder = '/projects/data/wlasl_2000/WLASL2000'

# %%
#train_file = pickle.load('')i# open a file, where you stored the pickled data
file = open('/projects/data/wlasl_2000/train.pkl', 'rb')

# dump information to that file
train_data = pickle.load(file)

# close the file
file.close()

# %%
train_data[:]

# %%
#train_file = pickle.load('')i# open a file, where you stored the pickled data
file = open('/projects/data/wlasl_2000/test.pkl', 'rb')

# dump information to that file
test_data = pickle.load(file)

# close the file
file.close()

# %%
#train_file = pickle.load('')i# open a file, where you stored the pickled data
file = open('/projects/data/wlasl_2000/dev.pkl', 'rb')

# dump information to that file
dev_data = pickle.load(file)

# close the file
file.close()

# %%
test_data
# Out:
# [{'video_file': 'WLASL2000/07092.mp4',
#   'name': '07092',
#   'seq_len': 78,
#   'label': 'book'},
#  {'video_file': 'WLASL2000/07093.mp4',
#   'name': '07093',
#   'seq_len': 85,
#   'label': 'book'},
#  {'video_file': 'WLASL2000/07095.mp4',
#   'name': '07095',
#   'seq_len': 86,
#   'label': 'book'},
#  {'video_file': 'WLASL2000/07072.mp4',
#   'name': '07072',
#   'seq_len': 18,
#   'label': 'book'},
#  {'video_file': 'WLASL2000/17730.mp4',
#   'name': '17730',
#   'seq_len': 69,
#   'label': 'drink'},
#  {'video_file': 'WLASL2000/17713.mp4',
#   'name': '17713',
#   'seq_len': 78,
#   'label': 'drink'},
#  {'video_file': 'WLASL2000/17716.mp4',
#   'name': '17716',
#   'seq_len': 57,
#   'label': 'drink'},
#  {'video_file': 'WLASL2000/17718.mp4',
#   'name': '17718',
#   'seq_len': 58,
#   'label': 'drink'},
#  {'video_file': 'WLASL2000/12306.mp4',
#   'name': '12306',
#   'seq_len': 52,
#   'label': 'computer'},
#  {'video_file': 'WLASL2000/12332.mp4',
#   'name': '12332',
# ...

# %%
# Opening JSON file
f = open('/projects/data/wlasl_2000/100.json')
 
# returns JSON object as
# a dictionary
data_100 = json.load(f)
 
# Iterating through the json
# list
for i in data_100:
    print(i,data_100[i])
 
# Closing file
f.close()
# Out:
# 05237 {'subset': 'train', 'action': [77, 1, 55]}
# 69422 {'subset': 'val', 'action': [27, 1, 51]}
# 10899 {'subset': 'train', 'action': [82, 1, 48]}
# 10898 {'subset': 'val', 'action': [82, 1, 39]}
# 10893 {'subset': 'train', 'action': [82, 1, 50]}
# 10892 {'subset': 'train', 'action': [82, 1, 203]}
# 10896 {'subset': 'train', 'action': [82, 1, 46]}
# 10895 {'subset': 'train', 'action': [82, 1, 108]}
# 10894 {'subset': 'train', 'action': [82, 1, 39]}
# 51069 {'subset': 'train', 'action': [46, 1, 55]}
# 51068 {'subset': 'test', 'action': [46, 1, 23], 'label': 'shirt'}
# 51064 {'subset': 'train', 'action': [46, 1, 83]}
# 51067 {'subset': 'val', 'action': [46, 1, 43]}
# 51066 {'subset': 'test', 'action': [46, 1, 87], 'label': 'shirt'}
# 51061 {'subset': 'train', 'action': [46, 1, 66]}
# 51060 {'subset': 'train', 'action': [46, 1, 41]}
# 66779 {'subset': 'train', 'action': [7, 1, 56]}
# 66778 {'subset': 'train', 'action': [7, 1, 60]}
# 65278 {'subset': 'train', 'action': [80, 1, 63]}
# ...

# %%
import os
import shutil
labels = []
for i in train_data:
    if i['name'] in data_100.keys():
        #print(i['label'])
        os.makedirs('/projects/data/wlasl_2000/wlasl_100_sorted/train/'+i['label'],exist_ok=True)
        shutil.copy('/projects/data/wlasl_2000/WLASL2000/'+i['name']+'.mp4','/projects/data/wlasl_2000/wlasl_100_sorted/train/'+i['label'])

        #labels.append(i['label'])
        
#print(len(set(labels)))
# Out:
# 0

# %%
labels = []
for i in test_data:
    if i['name'] in data_100.keys():
        #print(i['label'])
        os.makedirs('/projects/data/wlasl_2000/wlasl_100_sorted/test/'+i['label'],exist_ok=True)
        shutil.copy('/projects/data/wlasl_2000/WLASL2000/'+i['name']+'.mp4','/projects/data/wlasl_2000/wlasl_100_sorted/test/'+i['label'])

        #labels.append(i['label'])
        
#print(len(set(labels)))

# %%
labels = []
for i in dev_data:
    if i['name'] in data_100.keys():
        #print(i['label'])
        os.makedirs('/projects/data/wlasl_2000/wlasl_100_sorted/dev/'+i['label'],exist_ok=True)
        shutil.copy('/projects/data/wlasl_2000/WLASL2000/'+i['name']+'.mp4','/projects/data/wlasl_2000/wlasl_100_sorted/dev/'+i['label'])

        #labels.append(i['label'])
        
#print(len(set(labels)))
